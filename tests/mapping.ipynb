# %% [markdown]
# ## EDMT Mapping

# %%
# # install edmt
# %pip install git+https://github.com/envdmt/EDMT.git@eugene &> /dev/null

# %%
# import edmt to environment
import edmt
edmt.init()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # import edmt to environment
# ----> 2 import edmt
#       3 edmt.init()
#
# File ~/miniconda3/envs/edmt-test/lib/python3.13/site-packages/edmt/__init__.py:1
# ----> 1 from edmt import (
#       2     analysis,
#       3     base,
#       4     contrib,
#       5     conversion,
#       6     mapping,
#       7     models,
#       8     plotting
#       9     )
#      11 import importlib.metadata
#      13 ASCII = r"""
#      14  ___ ___  __  __ _____
#      15 | __|   \|  \/  |_   _|
#      16 | _|| |) | |\/| | | |
#      17 |___|___/|_|  |_| |_|
#      18 """
#
# File ~/miniconda3/envs/edmt-test/lib/python3.13/site-packages/edmt/mapping/__init__.py:5
#       1 from .maps import (
#       2     Mapping
#       3 )
# ----> 5 from .edmt_mapping import (
#       6     Map
#       7 )
# ...

# %%
import geopandas as gpd

# %%
gdf = gpd.read_file('ken_county.gpkg')

# %%
gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Shape_Leng  47 non-null     float64
#  1   Shape_Area  47 non-null     float64
#  2   ADM1_EN     47 non-null     object
#  3   ADM1_PCODE  47 non-null     object
#  4   ADM1_REF    1 non-null      object
#  5   ADM1ALT1EN  0 non-null      object
#  6   ADM1ALT2EN  0 non-null      object
#  7   ADM0_EN     47 non-null     object
#  8   ADM0_PCODE  47 non-null     object
#  9   date        47 non-null     object
#  10  validOn     47 non-null     object
#  11  validTo     0 non-null      object
#  12  geometry    47 non-null     geometry
# dtypes: float64(2), geometry(1), object(10)
# memory usage: 4.9+ KB

# %%
from edmt.mapping import edmt-mapping
# Out:
#   Cell In[8], line 1
#     from edmt.mapping import edmt-mapping
#                                  ^
# SyntaxError: invalid syntax
